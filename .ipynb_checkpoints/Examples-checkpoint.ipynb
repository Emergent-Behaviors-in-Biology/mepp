# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.backends import backend_pdf as bpdf
import matplotlib
import pickle
from scipy.special import kl_div
from scipy.optimize import brentq,minimize,LinearConstraint,Bounds,NonlinearConstraint
from scipy.integrate import solve_ivp
colors = sns.color_palette()
# %matplotlib inline

def plot_ZNGI(c,m,nR=100,Rmax=5,ax=None,flip=False,kind='substitutable'):
    if ax is None:
        fig,ax=plt.subplots()
    if kind == 'substitutable':
        #Shade uninvadable region
        Rcross = np.linalg.inv((c)).dot(m)
        R11 = np.linspace(0,Rcross[0],nR)
        R10 = np.linspace(Rcross[0],Rmax,nR)
        R21 = -c[1,0]*R11/(c[1,1]) + m[1]/(c[1,1])
        R20 = -c[0,0]*R10/(c[0,1]) + m[0]/(c[0,1])
        R10 = R10[R20>=0]
        R20 = R20[R20>=0]
        if flip:
            ax.fill_between(R10,R20,y2=Rmax*np.ones(len(R10)),color='gray')
            ax.fill_between(R11,R21,y2=Rmax*np.ones(len(R11)),color='gray')
        else:
            ax.fill_between(R10,R20,color='gray')
            ax.fill_between(R11,R21,color='gray')

        #Plot ZNGI's
        R = np.linspace(0,Rmax,100)
        ax.plot(R,m[0]/(c[0][1])-c[0][0]*R/(c[0][1]),color=colors[0],lw=3)
        ax.plot(R,m[1]/(c[1][1])-c[1][0]*R/(c[1][1]),color=colors[1],lw=3)
    
    else:
        Rstar1 = np.asarray([m[0]/c[0,0],m[0]/c[0,1]])
        Rstar2 = np.asarray([m[1]/c[1,0],m[1]/c[1,1]])
        ax.fill_between([0,np.min([Rstar1[0],Rstar2[0]])],[Rmax,Rmax],color='gray')
        ax.fill_between([np.min([Rstar1[0],Rstar2[0]]),np.max([Rstar1[0],Rstar2[0]])],np.max([Rstar1[1],Rstar2[1]])*np.ones(2),color='gray')
        ax.fill_between([np.max([Rstar1[0],Rstar2[0]]),Rmax],np.min([Rstar1[1],Rstar2[1]])*np.ones(2),color='gray')
        ax.plot([Rstar1[0],Rmax],[Rstar1[1],Rstar1[1]],color=colors[0])
        ax.plot([Rstar1[0],Rstar1[0]],[Rstar1[1],Rmax],color=colors[0])
        ax.plot([Rstar2[0],Rmax],[Rstar2[1],Rstar2[1]],color=colors[1])
        ax.plot([Rstar2[0],Rstar2[0]],[Rstar2[1],Rmax],color=colors[1])
        
    ax.axis('square')
    ax.set_xlim((0,Rmax))
    ax.set_ylim((0,Rmax))
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_xlabel('Resource 1', fontsize=12)
    ax.set_ylabel('Resource 2', fontsize=12)
    
def plot_d(d,params,f_values=np.linspace(0.1,15,20),Rmax=5,delta=0.01,ax=None):
    R1 = np.arange(0, Rmax, delta)
    R2 = np.arange(0, Rmax, delta)
    R1_mat, R2_mat = np.meshgrid(R1,R2)
    if ax is None:
        fig,ax = plt.subplots()
    CS = ax.contour(R1_mat, R2_mat, d(R1_mat.reshape(-1), R2_mat.reshape(-1), params).reshape(len(R1_mat),len(R1_mat)), f_values, colors='k',linestyles='dotted')

# %% [markdown]
# # Symmetric Models

# %% [markdown]
# ## Competition for noninteracting resources

# %% [markdown]
# \begin{align}
# \frac{dN_i}{dt} &= N_i \left[ \sum_{\alpha} w_\alpha c_{i\alpha} R_\alpha - m_i\right]\\
# \frac{dR_\alpha}{dt} &= \frac{r_\alpha}{K_\alpha} R_\alpha (K_\alpha - R_\alpha) - \sum_i N_i c_{i\alpha} R_\alpha.
# \end{align}
#
# \begin{align}
# d(\mathbf{R}^0,\mathbf{R}) &= \frac{1}{2}\sum_\alpha \frac{r_\alpha}{K_\alpha} w_\alpha (R_\alpha - R_\alpha^0)^2\\
# \sum_{\alpha} w_\alpha c_{i\alpha} R_\alpha &\leq m_i\\
# R_\alpha &\geq 0
# \end{align}

# %%
def d(R1,R2,params):
    return 0.5*((params['r'][0]/params['K'][0])*(R1-params['K'][0])**2
                +(params['r'][1]/params['K'][1])*(R2-params['K'][1])**2)

params = {'c':np.asarray([[0.5,0.3],[0.4,0.6]]),
          'r':np.asarray([1,1]),
          'K':np.asarray([4.8,2.85]),
          'm':np.asarray([1,1]),
          'w':np.asarray([1,1])}

def dydt(t,y):
    N = y[:2]
    R = y[2:]
    dNdt = N*((params['c']*params['w']).dot(R)-params['m'])
    dRdt = (params['r']/params['K'])*R*(params['K']-R) - params['c'].T.dot(N)*R 
    return np.hstack((dNdt,dRdt))
tmin = 0.1
tmax = 100
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((np.ones(2),np.ones(2))),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = out_ODE.y[:2,:].T
R = out_ODE.y[2:,:].T

fig,ax=plt.subplots(figsize=(3,3))
plot_d(d,params,ax=ax,f_values=np.linspace(0.1,5,15))
plot_ZNGI(params['c'],params['m'],ax=ax)
ax.plot([params['K'][0]],[params['K'][1]],'kx')
ax.plot([R[-1][0]],[R[-1][1]],'ko')
pdf = bpdf.PdfPages('Plots/MacArthur1_schem.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()

# %%
#Parameters
S = 10
M = 10
params = {'c':np.random.rand(S,M),
          'm':np.random.rand(S)+1,
          'w':np.random.rand(M)+1,
          'r':np.random.rand(M)+1,
          'K':np.random.rand(M)+5}
N_init = np.random.rand(S)
R_init = params['K']*0.1
tmin = 1
tmax= 1000

#ODE
def dydt(t,y):
    N = y[:S]
    R = y[S:]
    dNdt = N*((params['c']*params['w']).dot(R)-params['m'])
    dRdt = (params['r']/params['K'])*R*(params['K']-R) - (params['c'].T.dot(N))*R
    return np.hstack((dNdt,dRdt))
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((N_init,R_init)),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = out_ODE.y[:S,:].T
R = out_ODE.y[S:,:].T

#Constrained optimization
noninvadable = LinearConstraint(params['c']*params['w'],-np.inf*np.ones(S),params['m'])
resource_feasible = Bounds(0,np.inf)
def d(R):
    return 0.5*((R-params['K'])**2*params['w']*params['r']/params['K']).sum()
out_opt = minimize(d, R_init, method='trust-constr', constraints=noninvadable, bounds=resource_feasible)
Rstar = out_opt.x
Nstar = out_opt.v[0]

fig,ax=plt.subplots(2,sharex=True,figsize=(4,4))
fig.subplots_adjust(left=0.2)
#Plot ODE results
ax[0].loglog(t,N)
ax[1].loglog(t,R)
#Plot optimization results
if np.min(Nstar) < 0:
    print('Optimization Failed')
else:
    ax[0].set_prop_cycle(None)
    ax[0].plot([t[0],t[-1]],[Nstar,Nstar],'--')
    ax[1].set_prop_cycle(None)
    ax[1].plot([t[0],t[-1]],[Rstar,Rstar],'--')
    #Make legend
    ax[0].plot([],[],'k--',label='MEPP Prediction')
    ax[0].legend(loc=3)
#Make labels
ax[1].set_xlabel('Time')
ax[0].set_ylabel('Consumer Population')
ax[1].set_ylabel('Resource Abundance')
ax[0].set_ylim((1e-3,30))
ax[1].set_ylim((1e-4,10))
pdf = bpdf.PdfPages('Plots/MacArthur1_sim.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()

# %% [markdown]
# ## Interacting self-regulation

# %% [markdown]
# \begin{align}
# \frac{dN_i}{dt} &= N_i\left[ \sum_{\alpha} w_\alpha c_{i\alpha} R_\alpha - m_i\right]\\
# \frac{dR_\alpha}{dt} &= R_\alpha\left(1 - \sum_\beta w_\beta R_\beta \right) -  \sum_i c_{i\alpha} N_i R_\alpha.
# \end{align}
#
# \begin{align}
# d(\mathbf{R}) &=  \frac{1}{2}\left(1 - \sum_{\alpha} w_\alpha R_\alpha \right)^2\\
# \sum_{\alpha} w_\alpha c_{i\alpha} R_\alpha &\leq m_i\\
# R_\alpha &\geq 0
# \end{align}

# %%
def d(R1,R2,params):
    return 0.5*(1-params['w'][0]*R1-params['w'][1]*R2)**2

params = {'c':np.asarray([[0.5,0.3],[0.4,0.6]]),
          'm':np.asarray([.2,.22]),
          'w':np.asarray([0.2,0.15])}

#ODE
S = 2
M = 2
tmin = 0.1
tmax = 100000
N_init = np.ones(S)
R_init = np.ones(M)
#N_init = N[-1]
#R_init = R[-1]
def dydt(t,y):
    N = np.exp(y[:S])
    R = np.exp(y[S:])
    dlogNdt = ((params['c']*params['w']).dot(R)-params['m'])
    dlogRdt = (1-params['w'].dot(R)) - (params['c'].T.dot(N)).T
    return np.hstack((dlogNdt,dlogRdt))
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((np.log(N_init),np.log(R_init))),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = np.exp(out_ODE.y[:S,:].T)
R = np.exp(out_ODE.y[S:,:].T)

fig,ax=plt.subplots(figsize=(3,3))
plot_d(d,params,ax=ax,f_values=np.linspace(0.01,.5,15))
plot_ZNGI(params['c']*params['w'],params['m'],ax=ax)
R1 = np.linspace(0,5,100)
ax.plot(R1,(1-params['w'][0]*R1)/params['w'][1],'k',lw=3)
ax.plot([R[-1][0]],[R[-1][1]],'ko')
pdf = bpdf.PdfPages('Plots/MacArthur2_schem.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()

# %%
#Parameters
S = 10
M = 15
params = {'c':np.random.rand(S,M),
          'm':(np.random.rand(S)+1)/30,
          'w':(np.random.rand(M)+1)/20}
N_init = np.random.rand(S)
R_init = np.ones(M)/M
tmin = 1
tmax= 10000000

#ODE
def dydt(t,y):
    N = np.exp(y[:S])
    R = np.exp(y[S:])
    dlogNdt = ((params['c']*params['w']).dot(R)-params['m'])
    dlogRdt = (1-params['w'].dot(R)) - (params['c'].T.dot(N)).T
    return np.hstack((dlogNdt,dlogRdt))
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((np.log(N_init),np.log(R_init))),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = np.exp(out_ODE.y[:S,:].T)
R = np.exp(out_ODE.y[S:,:].T)

#Constrained optimization
noninvadable = LinearConstraint(params['c']*params['w'],-np.inf*np.ones(S),params['m'])
resource_feasible = Bounds(0,np.inf)
def d(R):
    return 0.5*(1 - params['w'].dot(R))**2
out_opt = minimize(d, R_init, method='trust-constr', constraints=noninvadable, bounds=resource_feasible)
Rstar = out_opt.x
Nstar = out_opt.v[0]

fig,ax=plt.subplots(2,sharex=True,figsize=(4,4))
fig.subplots_adjust(left=0.2)
#Plot ODE results
ax[0].loglog(t,N)
ax[1].loglog(t,R)
#Plot optimization results
if np.min(Nstar) < 0:
    print('Optimization Failed')
else:
    ax[0].set_prop_cycle(None)
    ax[0].plot([t[0],t[-1]],[Nstar,Nstar],'--')
    ax[1].set_prop_cycle(None)
    ax[1].plot([t[0],t[-1]],[Rstar,Rstar],'--')
    #Make legend
    ax[0].plot([],[],'k--',label='MEPP Prediction')
    ax[0].legend(loc=3)
#Make labels
ax[1].set_xlabel('Time')
ax[0].set_ylabel('Consumer Population')
ax[1].set_ylabel('Resource Abundance')
ax[0].set_ylim((1e-3,30))
ax[1].set_ylim((1e-3,10))
pdf = bpdf.PdfPages('Plots/MacArthur2_sim.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()

# %% [markdown]
# ## Competition to withstand predators

# %% [markdown]
# \begin{align}
# \frac{dN_i}{dt} &= N_i \left[ \sum_{\alpha} w_\alpha c_{i\alpha} R_\alpha - \sum_a p_{ia} P_a - m_i\right]\\
# \frac{dR_\alpha}{dt} &= \frac{r_\alpha}{K_\alpha} R_\alpha (K_\alpha - R_\alpha) - \sum_i N_i c_{i\alpha} R_\alpha\\
# \frac{dP_a}{dt} &= \sum_i p_{ia} N_i P_a - u_a P_a
# \end{align}
#
# \begin{align}
# d(\mathbf{R}^0,\mathbf{R}) &= \frac{1}{2}\sum_\alpha \frac{r_\alpha}{K_\alpha} w_\alpha (R_\alpha - K_\alpha)^2 + \sum_a u_a P_a\\
# \sum_{\alpha} w_\alpha c_{i\alpha} R_\alpha - \sum_a p_{ia} P_a &\leq m_i\\
# R_\alpha &\geq 0\\
# P_\alpha &\geq 0
# \end{align}

# %%
def d(R,P,params):
    return 0.5*(params['r']/params['K'])*(R-params['K'])**2+params['u']*P

params = {'c':np.asarray([0.5,0.4]),
          'p':np.asarray([0.3,0.6]),
          'm':np.asarray([1,.5]),
          'r':1,
          'K':4,
          'u':.5,
          'w':np.asarray([1])}

S = 2
MR = 1
N_init = np.ones(2)
P_init = np.ones(1)
R_init = np.ones(1)
tmin = 0.1
tmax = 1000
def dydt(t,y):
    N = y[:S]
    R = y[S:S+MR]
    P = y[S+MR:]
    dNdt = N*(params['c']*params['w']*R-params['p']*P-params['m'])
    dRdt = (params['r']/params['K'])*R*(params['K']-R) - (params['c'].T.dot(N))*R
    dPdt = (params['p'].T.dot(N))*P-params['u']*P
    return np.hstack((dNdt,dRdt,dPdt))
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((N_init,R_init,P_init)),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = out_ODE.y[:S,:].T
R = out_ODE.y[S:S+MR,:].T
P = out_ODE.y[S+MR:,:].T

fig,ax=plt.subplots(figsize=(3,3))
plot_d(d,params,ax=ax,f_values=np.linspace(0.1,8,15))
plot_ZNGI(np.vstack((params['c']*params['w'],-params['p'])).T,params['m'],ax=ax,flip=True)
ax.plot([params['K']],[0],'kx')
ax.plot([R[-1][0]],[P[-1][0]],'ko')
ax.set_xlabel('Resource')
ax.set_ylabel('Predator')
pdf = bpdf.PdfPages('Plots/MacArthur3_schem.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()

# %%
#Parameters
S = 10
MR = 10
MP = 10
params = {'c':np.random.rand(S,MR),
          'p':np.random.rand(S,MP),
          'm':np.random.rand(S)+1,
          'u':np.random.rand(MP)+1,
          'w':np.random.rand(MR)+1,
          'r':np.random.rand(MR)+1,
          'K':np.random.rand(MR)*5}
N_init = np.random.rand(S)
R_init = params['K']
P_init = np.random.rand(MP)+1
tmin = 1
tmax= 1000

#ODE
def dydt(t,y):
    N = y[:S]
    R = y[S:S+MR]
    P = y[S+MR:]
    dNdt = N*((params['c']*params['w']).dot(R)-params['p'].dot(P)-params['m'])
    dRdt = (params['r']/params['K'])*R*(params['K']-R) - (params['c'].T.dot(N))*R
    dPdt = (params['p'].T.dot(N))*P-params['u']*P
    return np.hstack((dNdt,dRdt,dPdt))
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((N_init,R_init,P_init)),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = out_ODE.y[:S,:].T
R = out_ODE.y[S:S+MR,:].T
P = out_ODE.y[S+MR:,:].T

#Constrained optimization
noninvadable = LinearConstraint(np.hstack((params['c']*params['w'],-params['p'])),-np.inf*np.ones(S),params['m'])
resource_feasible = Bounds(0,np.inf)
def d(RP):
    R = RP[:MR]
    P = RP[MR:]                   
    return 0.5*((R-params['K'])**2*params['w']*params['r']/params['K']).sum() + params['u'].dot(P)
out_opt = minimize(d, np.hstack((R_init,P_init)), method='trust-constr', constraints=noninvadable, bounds=resource_feasible)
Rstar = out_opt.x[:MR]
Pstar = out_opt.x[MR:]
Nstar = out_opt.v[0]

fig,ax=plt.subplots(3,sharex=True,figsize=(4,6))
fig.subplots_adjust(left=0.2)
#Plot ODE results
ax[0].loglog(t,N)
ax[1].loglog(t,R)
ax[2].loglog(t,P)
#Plot optimization results
if np.min(Nstar) < 0:
    print('Optimization Failed')
else:
    ax[0].set_prop_cycle(None)
    ax[0].plot([t[0],t[-1]],[Nstar,Nstar],'--')
    ax[1].set_prop_cycle(None)
    ax[1].plot([t[0],t[-1]],[Rstar,Rstar],'--')
    ax[2].set_prop_cycle(None)
    ax[2].plot([t[0],t[-1]],[Pstar,Pstar],'--')
    #Make legend
    ax[0].plot([],[],'k--',label='MEPP Prediction')
    ax[0].legend(loc=3)
#Make labels
ax[2].set_xlabel('Time')
ax[0].set_ylabel('Consumer Population')
ax[1].set_ylabel('Resource Abundance')
ax[2].set_ylabel('Predator Population')
ax[0].set_ylim((1e-3,10))
ax[1].set_ylim((1e-1,10))
ax[2].set_ylim((1e-1,30))
pdf = bpdf.PdfPages('Plots/MacArthur3_sim.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()

# %% [markdown]
# ## Chemostat

# %% [markdown]
# \begin{align}
# \frac{dN_i}{dt} &= N_i \left[ \sum_{\alpha} w_\alpha c_{i\alpha} R_\alpha - \tau^{-1}\right]\\
# \frac{dR_\alpha}{dt} &= \kappa_\alpha -\tau^{-1} R_\alpha - \sum_i N_i c_{i\alpha} R_\alpha.
# \end{align}
#
# \begin{align}
# d(\mathbf{R}^0,\mathbf{R}) &= \tau^{-1} \sum_\alpha w_\alpha\left[R_\alpha^0 \ln \frac{R_\alpha^0}{R_\alpha} - (R_\alpha^0 - R_\alpha)\right] \\
# R^0_\alpha &= \tau \kappa_\alpha
# \end{align}

# %%
def d(R1,R2,params):
    R0 = params['tau']*params['kappa']
    return (params['w'][0]*R0[0]*np.log(R0[0]/R1) + params['w'][1]*R0[1]*np.log(R0[1]/R2)
            -params['w'][0]*(R0[0]-R1)-params['w'][1]*(R0[1]-R2))/params['tau']

params = {'c':np.asarray([[0.5,0.3],[0.4,0.6]]),
          'tau':1,
          'kappa':np.asarray([4.8,2.5]),
          'm':np.asarray([1,1]),
          'w':np.asarray([1,1])}

tmin=1
tmax=1000
S=2
N_init=np.ones(2)
R_init=np.ones(2)
def dydt(t,y):
    N = y[:S]
    R = y[S:]
    dNdt = N*((params['c']*params['w']).dot(R)-1/params['tau'])
    dRdt = params['kappa']-R/params['tau'] - (params['c'].T.dot(N))*R
    return np.hstack((dNdt,dRdt))
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((N_init,R_init)),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = out_ODE.y[:S,:].T
R = out_ODE.y[S:,:].T

fig,ax=plt.subplots(figsize=(3,3))
plot_d(d,params,ax=ax,f_values=np.linspace(0.1,17,15))
plot_ZNGI(params['c'],params['m'],ax=ax)
ax.plot([params['kappa'][0]*params['tau']],[params['kappa'][1]*params['tau']],'kx')
ax.plot([R[-1][0]],[R[-1][1]],'ko')
pdf = bpdf.PdfPages('Plots/MacArthur4_schem.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
#Parameters
S = 9
M = 5
params = {'c':np.random.rand(S,M),
          'w':np.random.rand(M)+1,
          'tau':1,
          'kappa':np.random.rand(M)*6+1}
N_init = np.random.rand(S)
R_init = np.random.rand(M)
tmin = 1
tmax= 1000

#ODE
def dydt(t,y):
    N = y[:S]
    R = y[S:]
    dNdt = N*((params['c']*params['w']).dot(R)-1/params['tau'])
    dRdt = params['kappa'] - R/params['tau'] - (params['c'].T.dot(N))*R
    return np.hstack((dNdt,dRdt))
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((N_init,R_init)),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = out_ODE.y[:S,:].T
R = out_ODE.y[S:,:].T

#Constrained optimization
noninvadable = LinearConstraint(params['c']*params['w'],-np.inf*np.ones(S),np.ones(S)/params['tau'])
resource_feasible = Bounds(0,np.inf)
def d(R):
    return params['w'].dot(kl_div(params['kappa']*params['tau'],R))/params['tau']
def jac(R):
    return params['w']*(R-params['kappa']*params['tau'])/(R*params['tau'])
def hess(R):
    return np.diag(params['w']*params['kappa']*params['tau']/(R**2*params['tau']))
out_opt = minimize(d, R_init, method='trust-constr', constraints=noninvadable, bounds=resource_feasible, jac=jac, hess=hess)
Rstar = out_opt.x
Nstar = out_opt.v[0]

fig,ax=plt.subplots(2,sharex=True,figsize=(4,4))
fig.subplots_adjust(left=0.2)
#Plot ODE results
ax[0].loglog(t,N)
ax[1].loglog(t,R)
#Plot optimization results
ax[0].set_prop_cycle(None)
ax[0].plot([t[0],t[-1]],[Nstar,Nstar],'--')
ax[1].set_prop_cycle(None)
ax[1].plot([t[0],t[-1]],[Rstar,Rstar],'--')
#Make legend
ax[0].plot([],[],'k--',label='MEPP Prediction')
ax[0].legend(loc=3)
#Make labels
ax[1].set_xlabel('Time')
ax[0].set_ylabel('Consumer Population')
ax[1].set_ylabel('Resource Abundance')
ax[0].set_ylim((1e-1,100))
ax[1].set_ylim((1e-2,10))
pdf = bpdf.PdfPages('Plots/MacArthur4_sim.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()

# %% [markdown]
# ## Saturating

# %% [markdown]
# \begin{align}
# \frac{dN_i}{dt} &= e_i N_i \left[\frac{J_i \sum_\alpha w_\alpha c_{i\alpha}R_\alpha}{J_i + \sum_\alpha w_\alpha c_{i\alpha}R_\alpha} - m_i\right] - \tau^{-1}N_i\\
# \frac{dR_\alpha}{dt} &= \tau^{-1} (R_\alpha^0 - R_\alpha) - \sum_i N_i\frac{J_i c_{i\alpha}R_\alpha}{J_i+\sum_\beta w_\beta c_{i\beta}R_\beta}.
# \end{align}
#
# \begin{align}
# d(\mathbf{R}^0,\mathbf{R}) &= \tau^{-1} \sum_\alpha w_\alpha\left[R_\alpha^0 \ln \frac{R_\alpha^0}{R_\alpha} - (R_\alpha^0 - R_\alpha)\right]
# \end{align}

# %%
S = 2
M = 2
#Parameters taken from data analysis in Rothhaupt Analysis.ipynb
params = {'c':np.asarray([[0.427,0.211],[0.049,0.252]]),#np.random.rand(S,M),
          'e':np.asarray([13.8,72.8]),#np.random.rand(S)+3,
          'm':np.asarray([.0363,.00947]),#(np.random.rand(S)+1)/3,
          'w':np.ones(M),#np.random.rand(M)+1,
          'J':np.asarray([0.0927,0.0202]),#np.random.rand(S)+1,
          'tau':1/0.2,
          'R0':np.asarray([6,4])}#np.random.rand(M)+5}
N_init = np.asarray([10,10])
R_init = params['R0']
tmin = 1
tmax= 100

#ODE
def g(R):
    return params['e']*(params['J']*(params['c']*params['w']).dot(R)/(params['J']+(params['c']*params['w']).dot(R)) - params['m'])
def g_jac(R):
    return ((params['c']*params['w']).T*params['J']**2*params['e']/(params['J']+(params['c']*params['w']).dot(R))**2).T
def g_hess(R,v):
    return np.einsum('i,ij,ik',-v*2*params['J']**2*params['e']/(params['J']+(params['c']*params['w']).dot(R))**3,params['c']*params['w'],params['c']*params['w'])
def dydt(t,y):
    N = y[:S]
    R = y[S:]
    dNdt = N*(g(R)-1/params['tau'])
    dRdt = (params['R0']-R)/params['tau'] - (params['c']*R).T.dot(params['J']*N/(params['J']+(params['c']*params['w']).dot(R)))
    return np.hstack((dNdt,dRdt))
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((N_init,R_init)),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = out_ODE.y[:S,:].T
R = out_ODE.y[S:,:].T

#Constrained optimization
noninvadable = NonlinearConstraint(g,-np.inf,1/params['tau'],jac=g_jac,hess=g_hess)
resource_feasible = Bounds(0,np.inf)
def d(R):
    return params['w'].dot(kl_div(params['R0'],R))/params['tau']
def jac(R):
    return params['w']*(R-params['R0'])/(R*params['tau'])
def hess(R):
    return np.diag(params['w']*params['R0']/R**2)/params['tau']
out_opt = minimize(d, R_init, method='trust-constr', constraints=noninvadable, bounds=resource_feasible, jac=jac, hess=hess)
Rstar = out_opt.x
Nstar = out_opt.v[0]*params['J']*params['e']/(params['J']+(params['c']*params['w']).dot(Rstar))

fig,ax=plt.subplots(2,sharex=True,figsize=(4,4))
fig.subplots_adjust(left=0.2)
#Plot ODE results
ax[0].plot(t,N[:,1],label = 'B. rubens',color=colors[1])
ax[0].plot(t,N[:,0],label = 'B. caly.',color=colors[0])
ax[1].plot(t,R[:,0],label='Chlamy.',color=colors[2])
ax[1].plot(t,R[:,1],label='Mono.',color=colors[3])
#Plot optimization results
if np.min(Nstar) < 0:
    print('Optimization Failed')
else:
    ax[0].set_prop_cycle(None)
    ax[0].plot([t[0],t[-1]],[Nstar,Nstar],'--')
    ax[1].set_prop_cycle(None)
    ax[1].plot([t[0],t[-1]],[Rstar[0],Rstar[0]],'--',color=colors[2])
    ax[1].plot([t[0],t[-1]],[Rstar[1],Rstar[1]],'--',color=colors[3])
    #Make legend
    ax[0].plot([],[],'k--',label='MEPP Prediction')
    ax[0].legend(loc=2)
    ax[1].legend(loc=2)
#Make labels
ax[1].set_xlabel('Time (days)')
ax[0].set_ylabel(r'Animals (ml$^{-1}$)')
ax[1].set_ylabel('Algae ($\mu$gC/ml)')
ax[0].set_ylim((0,130))
ax[1].set_ylim((0,1))
ax[1].set_xlim((0,25))
pdf = bpdf.PdfPages('Plots/Rothhaupt_sim.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()

# %% [markdown]
# # Asymmetric models

# %% [markdown]
# ## Liebig's Law

# %% [markdown]
# \begin{align}
# \frac{dN_i}{dt} &= N_i \left[{\rm min}\left(\left\{\frac{\mu_{i\alpha} R_\alpha}{k_{i\alpha} + R_\alpha}\right\}\right) - \tau^{-1}\right]\\
# \frac{dR_\alpha}{dt} &= \kappa_\alpha - \tau^{-1} R_\alpha - \sum_{i} N_i \nu_{\alpha i} {\rm min}\left(\left\{\frac{\mu_{i\alpha} R_\alpha}{k_{i\alpha} + R_\alpha}\right\}\right).
# \end{align}
#
# \begin{align}
# d(\mathbf{R}^0,\mathbf{R}) &= \tau^{-1} \sum_\alpha w_\alpha \left[R_\alpha^0 \ln \frac{R_\alpha^0}{R_\alpha} - (R_\alpha^0 - R_\alpha)\right] \\
# R_\alpha^0 &= \tau \left(\kappa_\alpha - \sum_{\beta \neq \alpha} \bar{N}_\beta \nu_{\alpha \beta} {\rm min}\left(\left\{\frac{\mu_{i\alpha} R_\alpha}{k_{i\alpha} + R_\alpha}\right\}\right)\right)\\
# w_\alpha &= \frac{k_{\alpha\alpha}}{\nu_{\alpha\alpha}}
# \end{align}

# %%
def d(R1,R2,params):
    R0 = params['R0t']
    return (R0[0]*np.log(R0[0]/R1) + R0[1]*np.log(R0[1]/R2)
            -(R0[0]-R1)-(R0[1]-R2))/params['tau']

#Note: for this script to work, must have ones on the diagonal of nu, 
#off-diagonal elements less than one, and all k's the same value, so that 
#the weights are unity
params = {'mu':10*np.asarray([[0.6,0.9],[0.8,0.5]]),
          'k':np.ones((2,2))*10,
          'nu':np.asarray([[1,.7],[0.7,1]]),
          'tau':1,
          'kappa':np.asarray([4.3,4.3])}
#ODE
S=2
M=2
def g(R):
    return np.min((params['mu']*R)/(params['k']+np.ones(np.shape(params['k']))*R),axis=1)
tmin = 1
tmax= 1000
N_init = np.random.rand(2)
R_init = np.random.rand(2)
def dydt(t,y):
    N = y[:S]
    R = y[S:]
    dNdt = N*(g(R)-1/params['tau'])
    dRdt = params['kappa']- R/params['tau'] - params['nu'].T.dot(g(R)*N)
    return np.hstack((dNdt,dRdt))
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((N_init,R_init)),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = out_ODE.y[:S,:].T
R = out_ODE.y[S:,:].T
fig,ax=plt.subplots(2,sharex=True,figsize=(4,4))
fig.subplots_adjust(left=0.2)
#Plot ODE results
ax[0].loglog(t,N)
ax[1].semilogx(t,R)
#Make labels
ax[1].set_xlabel('Time')
ax[0].set_ylabel('Consumer Population')
ax[1].set_ylabel('Resource Abundance')
ax[0].set_ylim((1e-2,10))
ax[1].set_ylim((1e-2,10))
pdf = bpdf.PdfPages('Plots/Liebig_sim_small.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()

nu_nolim = params['nu']-np.diag(np.diag(params['nu']))
params['R0t'] = params['tau']*(params['kappa']-nu_nolim.T.dot(g(R[-1])*N[-1]))

fig,ax=plt.subplots(figsize=(3,3))
plot_d(d,params,ax=ax,f_values=np.linspace(0.1,5,15))
plot_ZNGI((params['mu']-1/params['tau'])/params['k'],np.ones(2)/params['tau'],ax=ax,kind='essential')
ax.plot([params['kappa'][0]*params['tau']],[params['kappa'][1]*params['tau']],'ks')
ax.plot([params['R0t'][0]],[params['R0t'][1]],'kx')
ax.plot([R[-1][0]],[R[-1][1]],'ko')
pdf = bpdf.PdfPages('Plots/Liebig_schem.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %% [markdown]
# Note: it's easy to generate sets of parameters that don't lead to stable fixed points. You have to try running this several times until you find one that works. If it works, it converges pretty fast.

# %%
#Parameters
S = 10
M = 3
params = {'mu':np.random.rand(S,M)*30,
          'k':(np.random.rand(S,M)*0.1+0.95)*30,
          'nu':np.random.rand(M,S),
          'tau':1,
          'kappa':np.random.rand(M)+20}
#Improve odds that system will be stable
params['nu'] = np.ones((M,S))/(params['mu']/params['k']).T + np.random.rand(M,S)*0.1
#Normalize
params['nu'] = params['nu']/params['nu'].sum(axis=0)

#Set up constraints
def g(R):
    return np.min((params['mu']*R)/(params['k']+np.ones(np.shape(params['k']))*R),axis=1)
def g_jac(R):
    jac = np.zeros((S,M))
    for k in range(S):
        jmin = np.argmin((params['mu'][k,:]*R)/(params['k'][k,:]+R))
        jac[k,jmin] = params['mu'][k,jmin]*params['k'][k,jmin]/(params['k'][k,jmin]+R[jmin])**2
    return jac
def g_hess(R,v):
    hess = np.zeros((M,M))
    for k in range(S):
        jmin = np.argmin((params['mu'][k,:]*R)/(params['k'][k,:]+R))
        hess[jmin,jmin] += -2*v[k]*params['mu'][k,jmin]*params['k'][k,jmin]/(params['k'][k,jmin]+R[jmin])**3
    return hess
noninvadable = NonlinearConstraint(g,-np.inf,1/params['tau'],jac=g_jac,hess=g_hess)
resource_feasible = Bounds(0,np.inf)

#Set up objective function
def effective_params(Rstar,aNstar):
    beta_i = np.asarray([np.argmin((params['mu'][k,:]*Rstar)/(params['k'][k,:]+Rstar)) for k in range(S)])
    a = params['k'][range(S),beta_i]+Rstar[beta_i]
    Nstar = aNstar/a
    nu_nolim = params['nu'].copy()
    nu_nolim[beta_i,range(S)] = 0
    R0t = params['tau']*(params['kappa']-nu_nolim.dot(g(Rstar)*Nstar))
    w = np.ones(M)
    w[beta_i[Nstar>0]] = params['k'][np.where(Nstar>0)[0],beta_i[Nstar>0]]/params['nu'][beta_i[Nstar>0],np.where(Nstar>0)[0]]
    return R0t, w, a
def d(R,Rstar,aNstar):
    R0t, w, a = effective_params(Rstar,aNstar)
    return w.dot(kl_div(R0t,R))
def jac(R,Rstar,aNstar):
    R0t, w, a = effective_params(Rstar,aNstar)
    return w*(R-R0t)/R
def hess(R,Rstar,aNstar):
    R0t, w, a = effective_params(Rstar,aNstar)
    return w*np.diag(R0t/R**2)

#Initialize optimization
Rstar = np.ones(M)
aNstar = np.ones(S)*1e-6
Rstar_old = np.zeros(M)
aNstar_old = np.ones(S)*100
eps = 1e-3
max_iter = 100
thresh=.5
k = 0

#Iteratively optimize, automatically updating effective supply point at each step
while (np.linalg.norm(Rstar-Rstar_old) > eps or np.linalg.norm(aNstar-aNstar_old) > eps) and k < max_iter:
    out_opt = minimize(lambda R: d(R,Rstar,aNstar), Rstar, method='trust-constr', constraints=noninvadable, bounds=resource_feasible, jac=lambda R: jac(R,Rstar,aNstar), hess=lambda R: hess(R,Rstar,aNstar),options={'maxiter':1e9})
    if out_opt.success:
        Rstar_old = Rstar
        aNstar_old = aNstar
        Rstar = out_opt.x
        aNstar = out_opt.v[0]
        aNstar[aNstar<thresh] = 0
        print(np.max(aNstar))
    else:
        print('Optimization failed')
        Rstar = Rstar*(1+np.random.randn(M)*0.3)
        aNstar = aNstar*(1+np.random.randn(S)*0.3)
    k+=1
R0t, w, a = effective_params(Rstar,aNstar)
Nstar = aNstar/a
    
#Solve ODE's, starting near the MEPP solution
N_init = Nstar*(1+0.3*np.random.randn(S))
N_init[N_init==0] = 5*np.random.rand(np.sum(N_init==0))
R_init = Rstar*(1+0.3*np.random.randn(M))
def dydt(t,y):
    N = y[:S]
    R = y[S:]
    dNdt = N*(g(R)-1/params['tau'])
    dRdt = params['kappa']-R/params['tau'] - params['nu'].dot(g(R)*N)
    return np.hstack((dNdt,dRdt))
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((N_init,R_init)),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = out_ODE.y[:S,:].T
R = out_ODE.y[S:,:].T

#Make plots
fig,ax=plt.subplots(2,sharex=True,figsize=(4,4))
fig.subplots_adjust(left=0.2)
#Plot ODE results
ax[0].loglog(t,N)
ax[1].semilogx(t,R)
#Plot optimization results
if np.min(Nstar) < 0:
    print('Optimization Failed')
else:
    ax[0].set_prop_cycle(None)
    ax[0].plot([t[0],t[-1]],[Nstar,Nstar],'--')
    ax[1].set_prop_cycle(None)
    ax[1].plot([t[0],t[-1]],[Rstar,Rstar],'--')
    #Make legend
    ax[0].plot([],[],'k--',label='MEPP Prediction')
    ax[0].legend(loc=3)
#Make labels
ax[1].set_xlabel('Time')
ax[0].set_ylabel('Consumer Population')
ax[1].set_ylabel('Resource Abundance')
ax[0].set_ylim((1e-1,100))
ax[1].set_ylim((1e-2,10))
pdf = bpdf.PdfPages('Plots/Liebig_sim.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()
# Out:
# 1128.5200449554898
# 817.112001236557
# 898.9031839888066
# 822.5203770353155
# 887.1574318897625
# 870.1791358416253
# 893.5032192280596
# 887.3775742309928
# 895.7883231380272
# 893.5790564532234
# 896.6139916014757
# 895.8167860233267
# 896.911930999877
# 896.6242623540913
# 897.019441315426
# 896.9156371624729
# 897.0582360099525
# 897.0207786703093
# 897.0722349301064
# 897.0587185894502
# 897.0772863879891
# 897.072409067109
# 897.0791091876388
# 897.0773492246798
# 897.0797669380653
# 897.0791318620217
# 897.0800042848401

# %% [markdown]
# ## Microbial Consumer Resource Model

# %% [markdown]
# \begin{align}
# \frac{dN_i}{dt} &= N_i \left[\sum_\alpha (1-l_\alpha) w_\alpha c_{i\alpha} R_\alpha - m_i\right]\\
# \frac{dR_\alpha}{dt} &= \kappa - \tau^{-1} R_\alpha - \sum_{i,\beta} N_i\frac{\delta_{\alpha\beta} - D_{\alpha\beta}l_\beta}{w_\alpha(1-l_\beta)}(1-l_\beta)w_\beta c_{i\beta}R_\beta
# \end{align}
#
# \begin{align}
# R_\alpha^0 = \tau\left(\kappa + \sum_i \bar{N}_i D_{\alpha\beta}l_\beta\frac{w_\beta}{w_\alpha} c_{i\beta}\bar{R}_\beta\right)
# \end{align}

# %%
#Parameters
S = 10
M = 5
params = {'c':np.random.rand(S,M),
          'm':np.random.rand(S)+1,
          'w':np.random.rand(M)+1,
          'l':np.random.rand(M),
          'tau':1,
          'D':np.random.dirichlet(np.ones(M)*10,size=M).T,
          'kappa':np.random.rand(M)*10}
N_init = np.random.rand(S)
R_init = np.random.rand(M)*0.1
tmin = 1
tmax= 1000

#ODE
def dydt(t,y):
    N = y[:S]
    R = y[S:]
    dNdt = N*((params['c']*params['w']*(1-params['l'])).dot(R)-params['m'])
    dRdt = params['kappa']-R/params['tau'] - (params['c'].T.dot(N))*R + (params['D']*params['l']).dot((params['c']*params['w']).T.dot(N)*R)/params['w']
    return np.hstack((dNdt,dRdt))
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((N_init,R_init)),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = out_ODE.y[:S,:].T
R = out_ODE.y[S:,:].T

#Constrained optimization
noninvadable = LinearConstraint(params['c']*params['w']*(1-params['l']),-np.inf*np.ones(S),params['m'])
resource_feasible = Bounds(0,np.inf)
def d(R,Rstar,Nstar):
    R0t = params['tau']*(params['kappa']+(params['D']*params['l']).dot((params['c']*params['w']).T.dot(Nstar)*Rstar)/params['w'])
    return ((1-params['l'])*params['w']).dot(kl_div(R0t,R))
def jac(R,Rstar,Nstar):
    R0t = params['tau']*(params['kappa']+(params['D']*params['l']).dot((params['c']*params['w']).T.dot(Nstar)*Rstar)/params['w'])
    return ((1-params['l'])*params['w'])*(R-R0t)/R
def hess(R,Rstar,Nstar):
    R0t = params['tau']*(params['kappa']+(params['D']*params['l']).dot((params['c']*params['w']).T.dot(Nstar)*Rstar)/params['w'])
    return np.diag(((1-params['l'])*params['w'])*R0t/R**2)
Rstar = np.ones(M)
Rstar_old = np.zeros(M)
eps = 1e-3
max_iter = 100
k = 0
Nstar = np.zeros(len(params['c']))
while np.linalg.norm(Rstar-Rstar_old) > eps and k < max_iter:
    out_opt = minimize(lambda R: d(R,Rstar,Nstar), Rstar, method='trust-constr', constraints=noninvadable, bounds=resource_feasible, jac=lambda R: jac(R,Rstar,Nstar), hess=lambda R: hess(R,Rstar,Nstar))
    Rstar_old = Rstar
    Rstar = out_opt.x
    Nstar = out_opt.v[0]
    k+=1


fig,ax=plt.subplots(2,sharex=True,figsize=(4,4))
fig.subplots_adjust(left=0.2)
#Plot ODE results
ax[0].loglog(t,N)
ax[1].loglog(t,R)
#Plot optimization results
if np.min(Nstar) < 0:
    print('Optimization Failed')
else:
    ax[0].set_prop_cycle(None)
    ax[0].plot([t[0],t[-1]],[Nstar,Nstar],'--')
    ax[1].set_prop_cycle(None)
    ax[1].plot([t[0],t[-1]],[Rstar,Rstar],'--')
    #Make legend
    ax[0].plot([],[],'k--',label='MEPP Prediction')
    ax[0].legend(loc=3)
#Make labels
ax[1].set_xlabel('Time')
ax[0].set_ylabel('Consumer Population')
ax[1].set_ylabel('Resource Abundance')
ax[0].set_ylim((1e-1,100))
ax[1].set_ylim((1e-2,5))
pdf = bpdf.PdfPages('Plots/MiCRM_sim.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()

# %%
def d(R1,R2,params):
    R0 = params['R0t']
    return (params['w'][0]*R0[0]*np.log(R0[0]/R1) + params['w'][1]*R0[1]*np.log(R0[1]/R2)
            -params['w'][0]*(R0[0]-R1)-params['w'][1]*(R0[1]-R2))/params['tau']

c = np.asarray([[0.5,0.3],[0.4,0.6]])
D = np.asarray([[0,1],[1,0]])
R0 = [4.5,0.9]
l=0.5
m=2
params={'c':c,
        'D':D,
        'm':m*(1-l)*np.ones(2),
        'l':l*np.ones(2),
        'w':np.ones(2),
        'g':1,
        'kappa':np.asarray(R0),
        'tau':1.
       }
#ODE
tmin = 1
tmax= 1000
N_init = np.random.rand(2)
R_init = np.random.rand(2)
S=2
def dydt(t,y):
    N = y[:S]
    R = y[S:]
    dNdt = N*((1-params['l'])*(params['c']*params['w']).dot(R)-params['m'])
    dRdt = params['kappa']- R/params['tau'] - params['c'].T.dot(N)*R + params['l']*params['D'].dot((params['c']*params['w']*R).T.dot(N))/params['w']
    return np.hstack((dNdt,dRdt))
out_ODE = solve_ivp(dydt,(tmin,tmax),np.hstack((N_init,R_init)),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
N = out_ODE.y[:S,:].T
R = out_ODE.y[S:,:].T
fig,ax=plt.subplots(2,sharex=True,figsize=(4,4))
fig.subplots_adjust(left=0.2)
#Plot ODE results
ax[0].loglog(t,N)
ax[1].semilogx(t,R)
#Make labels
ax[1].set_xlabel('Time')
ax[0].set_ylabel('Consumer Population')
ax[1].set_ylabel('Resource Abundance')
ax[0].set_ylim((1e-2,10))
ax[1].set_ylim((1e-2,10))
pdf = bpdf.PdfPages('Plots/MiCRM_sim_small.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()


params['R0t'] = params['tau']*(params['kappa']+(params['D']*params['l']).dot((params['c']*params['w']).T.dot(N[-1])*R[-1])/params['w'])
fig,ax=plt.subplots(figsize=(3,3))
plot_d(d,params,ax=ax,f_values=np.linspace(0.1,7,25))
plot_ZNGI((1-params['l'])*params['c']*params['w'],params['m'],ax=ax)
ax.plot([params['kappa'][0]*params['tau']],[params['kappa'][1]*params['tau']],'ks')
ax.plot([params['R0t'][0]],[params['R0t'][1]],'kx')
ax.plot([R[-1][0]],[R[-1][1]],'ko')
pdf = bpdf.PdfPages('Plots/MiCRM_schem.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %% [markdown]
# # Evolution

# %% [markdown]
# Look at Schreiber and Tobiason (2003) class of consumer-resource models, as used in Koffel et al. (2016).

# %% [markdown]
# Summary:
# - $\alpha = -5$ (using mass-conseriving impact vectors, different from case examined in Koffel et al.) drives strategy to unstable fixed point, from where it hops to the other equilibrium point, and so on, leading to oscillatory evolutionary trajectory.
# - $\alpha = 2$ (same as Koffel et al.) drives system to branch point, get clean gradient-ascent-like dynamics in $d$

# %% [markdown]
# ## Single species

# %%
xvec=np.linspace(0.05,0.99,100)
params={'alpha':-5,
       'm':1,
       'S':np.asarray([5,5]),
       'l':np.ones(2)}
R_init1 = np.asarray([params['S'][0]-1,params['m']])
R_init2 = np.asarray([params['m'],params['S'][1]-1])
def g(R,x):
    return ((x*R[0])**params['alpha']+((1-x)*R[1])**params['alpha'])**(1/params['alpha'])
def g_jac(R,x):
    return np.asarray([x**params['alpha']*R[0]**(params['alpha']-1),(1-x)**params['alpha']*R[1]**(params['alpha']-1)])*g(R,x)**(1-params['alpha'])
def g_hess(R,x,v):
    h1 = (params['alpha']-1)*g_jac(R,x)*np.asarray([1/R[0]-g_jac(R,x)[0]/g(R,x),-g_jac(R,x)[0]/g(R,x)])
    h2 = (params['alpha']-1)*g_jac(R,x)*np.asarray([-g_jac(R,x)[1]/g(R,x),1/R[1]-g_jac(R,x)[1]/g(R,x)])
    h = np.asarray([h1,h2])
    return h
def d(R):
    return params['l'].dot(kl_div(params['S'],R))
def jac(R):
    return params['l']*(R-params['S'])/(R)
def hess(R):
    return np.diag(params['l']*params['S']/(R**2))

Rlist1 = []
Rlist2 = []
dlist1 = []
dlist2 = []
for x in xvec:
    noninvadable = NonlinearConstraint(lambda R: g(R,x),-np.inf,params['m'],jac=lambda R: g_jac(R,x),hess=lambda R, v: g_hess(R,x,v))
    resource_feasible = Bounds(0,np.inf)
    out_opt = minimize(d, R_init1, method='trust-constr', constraints=noninvadable, bounds=resource_feasible, jac=jac, hess=hess)
    Rlist1.append(out_opt.x)
    dlist1.append(out_opt.fun)
    out_opt = minimize(d, R_init2, method='trust-constr', constraints=noninvadable, bounds=resource_feasible, jac=jac, hess=hess)
    Rlist2.append(out_opt.x)
    dlist2.append(out_opt.fun)
Rlist1 = np.asarray(Rlist1)
dlist1 = np.asarray(dlist1)
Rlist2 = np.asarray(Rlist2)
dlist2 = np.asarray(dlist2)

# %%
plt.plot(xvec,dlist1)
plt.show()

# %%
#ODE
tmin = 1
tmax= 1000
N_init = np.ones(2)#N[-1]#N_old[-1]+0.1*np.ones(2)
R_init = R_init1#R[-1]#R_old[-1]#R_init1
S=2
x1=0.35
x2=0.3
def dydt(t,y,x1,x2):
    N = np.exp(y[:S])
    R = y[S:]
    dlogNdt = np.asarray([g(R,x1)-params['m'],g(R,x2)-params['m']])
    dRdt = params['l']*(params['S']- R) - (N[0]*g_jac(R,x1)+N[1]*g_jac(R,x2))*R
    return np.hstack((dlogNdt,dRdt))
out_ODE = solve_ivp(lambda t,y: dydt(t,y,x1,x2),(tmin,tmax),np.hstack((np.log(N_init),R_init)),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),1000))
t = out_ODE.t
#N_old = N
#R_old = R
N = np.exp(out_ODE.y[:S,:].T)
R = out_ODE.y[S:,:].T
fig,ax=plt.subplots(2,sharex=True,figsize=(4,4))
fig.subplots_adjust(left=0.2)
#Plot ODE results
ax[0].semilogx(t,N)
ax[1].semilogx(t,R)
#Make labels
ax[1].set_xlabel('Time')
ax[0].set_ylabel('Consumer Population')
ax[1].set_ylabel('Resource Abundance')
plt.show()

# %%
def env(R1):
    exp = params['alpha']/(1-params['alpha'])
    return (params['m']**exp-R1**exp)**(1/exp)
def env1(R1,x):
    exp = params['alpha']
    return (params['m']**exp-(x*R1)**exp)**(1/exp)/(1-x)

fig,ax=plt.subplots(figsize=(4,4))
R1vec = np.linspace(0.1,6,10000)
ax.plot(R1vec,env(R1vec))
ax.plot(R1vec,env1(R1vec,0.5))
ax.plot(R1vec,env1(R1vec,0.3))
ax.plot(Rlist1[:,0],Rlist1[:,1])
ax.plot(Rlist2[:,0],Rlist2[:,1])
ax.plot([R[-1][0]],[R[-1][1]],'kx')
ax.set_ylim((1,2))
ax.set_xlim((1,2))
plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in power
#   This is separate from the ipykernel package so we can avoid doing imports until
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in sqrt

# %% [markdown]
# ## Evolutionary trajectory, allowing for branching

# %%
tmin = 1
tmax= 5000
S=4

thresh = 1e-2
x1 = 0.4
x2 = np.nan
xtraj = [(x1,x2)]
Rtraj = []
N_init = np.ones(S)*thresh/2
R_init = R_init1
def dydt(t,y,x):
    N = np.exp(y[:S])
    nonzero = ~np.isnan(x)
    N_nz = N[nonzero]
    x_nz = x[nonzero]
    R = y[S:]
    dlogNdt = np.zeros(S)
    dlogNdt[nonzero] = np.asarray([g(R,x_nz[k])-params['m'] for k in range(len(x_nz))])
    dRdt = params['l']*(params['S']- R) - np.sum(np.asarray([N_nz[k]*g_jac(R,x_nz[k]) for k in range(len(x_nz))]),axis=0)*R
    return np.hstack((dlogNdt,dRdt))

for k in range(200):
    x3 = np.abs(x1+np.random.randn()*0.02)
    x3 = 1-np.abs(1-x3)
    if not np.isnan(x2):
        x4 = np.abs(x2+np.random.randn()*0.02)
        x4 = 1-np.abs(1-x4)
    else:
        x4 = np.nan
    x = np.asarray([x1,x2,x3,x4])
    out_ODE = solve_ivp(lambda t,y: dydt(t,y,x),(tmin,tmax),np.hstack((np.log(N_init),R_init)),t_eval=np.logspace(np.log10(tmin),np.log10(tmax),50)[1:-1])
    N = np.exp(out_ODE.y[:S,:].T)
    R = out_ODE.y[S:,:].T
    survive = N[-1] > thresh
    print(x)
    print(N[-1])
    R_init = R[-1]
    N_init = thresh*np.ones(S)/2
    Rtraj.append(list(R[-1]))
    N_init[:np.sum(survive)] = N[-1][survive]
    x_old = x
    x = np.nan*np.ones(4)
    x[:np.sum(survive)] = x_old[survive]
    x1 = x[0]
    x2 = x[1]
    xtraj.append((x1,x2))
xtraj = np.asarray(xtraj)    
Rtraj = np.asarray(Rtraj)

xtraj2 = np.sort(xtraj,axis=1)
xtraj2[np.isnan(xtraj2[:,1]),1] = xtraj2[np.isnan(xtraj2[:,1]),0]
pd.DataFrame(xtraj2,columns=['x1','x2']).to_csv('Data/alpha'+str(params['alpha'])+'_traits.csv')
pd.DataFrame(Rtraj,columns=['R1','R2']).to_csv('Data/alpha'+str(params['alpha'])+'_env.csv')

fig,ax=plt.subplots()
ax.plot(xtraj2[:,0])
ax.plot(xtraj2[:,1])
ax.set_xlabel('Cumulative mutations')
ax.set_ylabel('Trait value')
pdf = bpdf.PdfPages('Plots/alpha'+str(params['alpha'])+'_traj.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()
# Out:
# [0.4               nan 0.42205979        nan]
# [1.67916437e-95 5.00000000e-03 1.13387278e+00 5.00000000e-03]
# [0.42205979        nan 0.46126849        nan]
# [3.18491723e-152 5.00000000e-003 1.33826358e+000 5.00000000e-003]
# [0.46126849        nan 0.45520584        nan]
# [1.33822339e+00 5.00000000e-03 1.02943158e-26 5.00000000e-03]
# [0.46126849        nan 0.46648216        nan]
# [2.59114703e-18 5.00000000e-03 1.36384002e+00 5.00000000e-03]
# [0.46648216        nan 0.46052308        nan]
# [1.36354107e+00 5.00000000e-03 4.95739932e-26 5.00000000e-03]
# [0.46648216        nan 0.43816839        nan]
# [1.36370894e+000 5.00000000e-003 1.18109094e-112 5.00000000e-003]
# [0.46648216        nan 0.43630469        nan]
# [1.36389668e+000 5.00000000e-003 6.78807261e-120 5.00000000e-003]
# [0.46648216        nan 0.43829676        nan]
# [1.36392763e+000 5.00000000e-003 3.72291059e-112 5.00000000e-003]
# [0.46648216        nan 0.47602783        nan]
# [2.90378664e-34 5.00000000e-03 1.40733174e+00 5.00000000e-03]
# [0.47602783        nan 0.47271743        nan]
# [1.40695789e+00 5.00000000e-03 1.58933524e-15 5.00000000e-03]
# [0.47602783        nan 0.46812726        nan]
# [0.51184117        nan 0.54163346        nan]
# [3.16489415e+000 5.00000000e-003 4.62564168e-102 5.00000000e-003]
# [0.51184117        nan 0.49983066        nan]
# [1.33492988e-33 5.00000000e-03 3.28687918e+00 5.00000000e-03]
# [0.49983066        nan 0.52094285        nan]
# [3.28404734e+00 5.00000000e-03 9.14356886e-68 5.00000000e-03]
# [0.49983066        nan 0.46056099        nan]
# [1.51124867e+000 5.00000000e-003 2.46390167e-139 5.00000000e-003]
# [0.49983066        nan 0.47581844        nan]
# [1.51062499e+00 5.00000000e-03 2.65940612e-89 5.00000000e-03]
# [0.49983066        nan 0.49852592        nan]
# [1.51125640e+00 5.00000000e-03 1.08072304e-07 5.00000000e-03]
# [0.49983066        nan 0.4836043         nan]
# [1.51056954e+00 5.00000000e-03 3.05108067e-61 5.00000000e-03]
# [0.49983066        nan 0.50874712        nan]
# [2.09333231e-29 5.00000000e-03 1.54673457e+00 5.00000000e-03]
# [0.50874712        nan 0.49597099        nan]
# [1.54757459e+00 5.00000000e-03 6.21462577e-48 5.00000000e-03]
# [0.50874712        nan 0.48597755        nan]
# [1.54857084e+00 5.00000000e-03 3.11664849e-83 5.00000000e-03]

# %%
def env(R1):
    exp = params['alpha']/(1-params['alpha'])
    return (params['m']**exp-R1**exp)**(1/exp)
def env1(R1,x):
    exp = params['alpha']
    return (params['m']**exp-(x*R1)**exp)**(1/exp)/(1-x)

fig,ax=plt.subplots(figsize=(4,4))
R1vec = np.linspace(0.1,6,10000)
ax.plot(R1vec,env(R1vec))
ax.plot(R1vec,env1(R1vec,0.7))
ax.plot(R1vec,env1(R1vec,0.4))
ax.plot([1,1],[0,6])
ax.plot([0,6],[1,1])
ax.plot(Rtraj[:,0],Rtraj[:,1],'o')
ax.set_ylim((0,6))
ax.set_xlim((0,6))
plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in power
#   This is separate from the ipykernel package so we can avoid doing imports until
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in power

# %% [markdown]
# ###### Two species

# %%
x1vec=np.linspace(0.01,0.99,30)
x2vec=np.linspace(0.01,0.99,30)
x1vec,x2vec = np.meshgrid(x1vec,x2vec)
params={'alpha':2,
       'm':1,
       'S':np.ones(2)*5,
       'l':np.ones(2)}
R_init = np.asarray([params['S'][0]-1,params['m']])
#R_init2 = np.asarray([params['m'],params['S'][1]-1])
def g(R,x):
    return ((x*R[0])**params['alpha']+((1-x)*R[1])**params['alpha'])**(1/params['alpha'])
def g_jac(R,x):
    return np.asarray([x**params['alpha']*R[0]**(params['alpha']-1),(1-x)**params['alpha']*R[1]**(params['alpha']-1)])*g(R,x)**(1-params['alpha'])
def g_hess(R,x):
    h1 = (params['alpha']-1)*g_jac(R,x)*np.asarray([1/R[0]-g_jac(R,x)[0]/g(R,x),-g_jac(R,x)[0]/g(R,x)])
    h2 = (params['alpha']-1)*g_jac(R,x)*np.asarray([-g_jac(R,x)[1]/g(R,x),1/R[1]-g_jac(R,x)[1]/g(R,x)])
    h = np.asarray([h1,h2])
    return h
def d(R):
    return params['l'].dot(kl_div(params['S'],R))
def jac(R):
    return params['l']*(R-params['S'])/(R)
def hess(R):
    return np.diag(params['l']*params['S']/(R**2))

Rlist = []
Nlist = []
dlist = []
for k in range(len(x1vec.reshape(-1))):
    x1 = x1vec.reshape(-1)[k]
    x2 = x2vec.reshape(-1)[k]
    noninvadable = NonlinearConstraint(lambda R: np.asarray([g(R,x1),g(R,x2)]),-np.inf,params['m'],jac=lambda R: np.asarray([g_jac(R,x1),g_jac(R,x2)]),hess=lambda R, v: v[0]*g_hess(R,x1)+v[1]*g_hess(R,x2))
    resource_feasible = Bounds(0,np.inf)
    out_opt = minimize(d, R_init, method='trust-constr', constraints=noninvadable, bounds=resource_feasible, jac=jac, hess=hess)
    Rlist.append(out_opt.x)
    dlist.append(out_opt.fun)
    Nlist.append(out_opt.v[0])
Rlist = np.asarray(Rlist)
dlist = np.asarray(dlist).reshape(x1vec.shape)
Nlist = np.asarray(Nlist)

fig,ax=plt.subplots()
ax.contour(x1vec,x2vec,dlist)
plt.show()

# %%
xtraj2 = pd.read_csv('Data/alpha'+str(params['alpha'])+'_traits.csv',index_col=0).values

fig,ax=plt.subplots(figsize=(3,3))
fig.subplots_adjust(left=0.2,bottom=0.2)
ax.contour(x1vec,x2vec,dlist)
ax.plot(xtraj2[:,0],xtraj2[:,1],'k')
ax.set_xlim((-0.01,1.01))
ax.set_ylim((-0.01,1.01))
ax.set_xlabel(r'Species 1 trait value $x_1$')
ax.set_ylabel(r'Species 2 trait value $x_2$')
pdf = bpdf.PdfPages('Plots/alpha'+str(params['alpha'])+'_contours.pdf')
pdf.savefig(fig)
pdf.close()
plt.show()

# %%
def env(R1):
    exp = params['alpha']/(1-params['alpha'])
    return (params['m']**exp-R1**exp)**(1/exp)
def env1(R1,x):
    exp = params['alpha']
    return (params['m']**exp-(x*R1)**exp)**(1/exp)/(1-x)
def d(R1,R2,params):
    R0 = params['S']
    return (params['l'][0]*R0[0]*np.log(R0[0]/R1) + params['l'][1]*R0[1]*np.log(R0[1]/R2)
            -params['l'][0]*(R0[0]-R1)-params['l'][1]*(R0[1]-R2))


fig,ax=plt.subplots(figsize=(4,4))
plot_d(d,params,ax=ax,f_values=np.linspace(0.1,17,15))
R1vec = np.linspace(0.1,6,10000)
ax.plot(R1vec,env(R1vec))
#ax.plot(R1vec,env1(R1vec,0.6))
#ax.plot(R1vec,env1(R1vec,0.4))
plt.plot(Rlist2[:,0],Rlist2[:,1])
#plt.plot(Rlist[:,0],Rlist[:,1],'o',ms=1)
ax.plot([1,1],[0,6])
ax.plot([0,6],[1,1])
ax.plot(Rtraj[:,0],Rtraj[:,1],'o')
ax.set_ylim((0,2.5))
ax.set_xlim((0,2.5))
plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in power
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def env1(R1,x):
    exp = params['alpha']
    return (params['m']**exp-(x*R1)**exp)**(1/exp)/(1-x)

fig,ax=plt.subplots(figsize=(4,4))
R1vec = np.linspace(0.1,6,10000)
for x in np.linspace(0.05,0.95,10):
    ax.plot(R1vec,env1(R1vec,x),'k',lw=1)
ax.plot([1,1],[0,6])
ax.plot([0,6],[1,1])
ax.set_ylim((0,2.5))
ax.set_xlim((0,2.5))
plt.show()
